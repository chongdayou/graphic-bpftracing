# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from matplotlib.lines import Line2D
from PIL import Image

# %%
cpu_count = 'All'
file_path = 'trace_mutex_latency_' + cpu_count + '_CPU_results.csv'

# %%
stats = defaultdict(list)
with open(file_path, 'r') as file:
    ms_past = 0
    for line in file:
        if 'Averages' in line:
            ms_past = int(line[line.find('@')+1:line.find('ms')])
        if line[:19] == '@mutex_latency_avgs':
            tid = int(line[20:line.find(']')])
            avg = int(line[line.find(':')+2:])
            stats[tid].append( (ms_past,avg) )

# %%
print(stats)
# Out:
# defaultdict(<class 'list'>, {28076: [(100, 27360), (110, 39085)], 28079: [(100, 30995), (110, 29140), (120, 32868), (130, 34098), (140, 49424)], 28080: [(100, 31025), (110, 33277), (120, 28965), (130, 29331), (140, 14581)], 28077: [(100, 32938), (110, 39332), (120, 27368), (130, 35949), (140, 158348)], 28078: [(100, 41919), (110, 35946), (120, 26891), (130, 37540), (140, 18894)]})

# %%
plt.figure(figsize=(10,5))
plt.xlabel('ms past since process starts')
plt.ylabel('avg ns mutex hold latency')

for tid, points in stats.items():
    x_values = [p[0] for p in points]
    y_values = [p[1] for p in points]
    plt.plot(x_values, y_values, alpha=0.8, lw=2)

plt.xticks(np.arange(90, 181, 10))

plt.savefig('plots/latency_avg_over_time_' + cpu_count + '_CPU.png', dpi=300)
plt.close()
